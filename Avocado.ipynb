# %% [markdown]
#  Avocado prices data ://www.kaggle.com/datasets/neuromusic/avocado-prices?resource=download
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **import libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# https://facebook.github.io/prophet/

# %%
pip install prophet

# %%
from prophet import Prophet

# %% [markdown]
# #TSF case study

# %% [markdown]
# load data

# %%
import pandas as pd
avo=pd.read_csv('/content/avocado.csv')
display(avo.head())
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %% [markdown]
# #EDA

# %%
avo.shape
# Out:
# (18249, 14)

# %%
avo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
avo.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %%
avo. isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
avo['Date']
# Out:
# 0        2015-12-27
# 1        2015-12-20
# 2        2015-12-13
# 3        2015-12-06
# 4        2015-11-29
#             ...
# 18244    2018-02-04
# 18245    2018-01-28
# 18246    2018-01-21
# 18247    2018-01-14
# 18248    2018-01-07
# Name: Date, Length: 18249, dtype: object

# %%
avo.sort_values(by='Date',ascending=True)
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume        4046  \
# 11569          51  2015-01-04          1.75      27365.89     9307.34
# 9593           51  2015-01-04          1.49      17723.17     1189.35
# 10009          51  2015-01-04          1.68       2896.72      161.68
# 1819           51  2015-01-04          1.52      54956.80     3013.04
# 9333           51  2015-01-04          1.64       1505.12        1.27
# ...           ...         ...           ...           ...         ...
# 8574            0  2018-03-25          1.36     908202.13   142681.06
# 9018            0  2018-03-25          0.70    9010588.32  3999735.71
# 18141           0  2018-03-25          1.42     163496.70    29253.30
# 17673           0  2018-03-25          1.70     190257.38    29644.09
# 8814            0  2018-03-25          1.34    1774776.77    63905.98
#
#             4225       4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# ...

# %%
avo['Date'] = pd.to_datetime(avo['Date'])
plt.plot(avo['Date'], avo['AveragePrice'])
plt.xlabel('Date')
plt.ylabel('Average Price')
plt.title('Average Avocado Price Over Time')
plt.show()

# %%
sns.countplot(x='year',data=avo)
# Out:
# <Axes: xlabel='year', ylabel='count'>

# %% [markdown]
# #preprocessing

# %%
avo_prophet = avo[['Date', 'AveragePrice']]
avo_prophet.columns = ['ds', 'y']

# %%
avo_prophet.head()
# Out:
#           ds     y
# 0 2015-12-27  1.33
# 1 2015-12-20  1.35
# 2 2015-12-13  0.93
# 3 2015-12-06  1.08
# 4 2015-11-29  1.28

# %%
model=Prophet()
model.fit(avo_prophet)
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmplubi3yo_/95b522dd.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmplubi3yo_/gmbujztq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=38918', 'data', 'file=/tmp/tmplubi3yo_/95b522dd.json', 'init=/tmp/tmplubi3yo_/gmbujztq.json', 'output', 'file=/tmp/tmplubi3yo_/prophet_modelpqq7keiz/prophet_model-20250820163111.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:31:11 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:31:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
future=model.make_future_dataframe(periods=365)

# %%
future
# Out:
#             ds
# 0   2015-01-04
# 1   2015-01-11
# 2   2015-01-18
# 3   2015-01-25
# 4   2015-02-01
# ..         ...
# 529 2019-03-21
# 530 2019-03-22
# 531 2019-03-23
# 532 2019-03-24
# 533 2019-03-25
#
# [534 rows x 1 columns]

# %%
forecast=model.predict(future)

# %%
forecast
# Out:
#             ds     trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0   2015-01-04  1.497844    0.929515    1.871531     1.497844     1.497844
# 1   2015-01-11  1.492670    0.917477    1.876433     1.492670     1.492670
# 2   2015-01-18  1.487497    0.891497    1.894913     1.487497     1.487497
# 3   2015-01-25  1.482324    0.921002    1.847334     1.482324     1.482324
# 4   2015-02-01  1.477150    0.814734    1.824705     1.477150     1.477150
# ..         ...       ...         ...         ...          ...          ...
# 529 2019-03-21  1.158785    0.574727    1.577600     0.961506     1.350910
# 530 2019-03-22  1.158046    0.516099    1.566095     0.959660     1.351358
# 531 2019-03-23  1.157307    0.556988    1.612352     0.958060     1.351846
# 532 2019-03-24  1.156569    0.570104    1.585825     0.956460     1.352317
# 533 2019-03-25  1.155830    0.536074    1.616095     0.954708     1.352479
#
# ...

# %%
forecast[['ds','yhat','yhat_lower','yhat_upper']]
# Out:
#             ds      yhat  yhat_lower  yhat_upper
# 0   2015-01-04  1.383556    0.929515    1.871531
# 1   2015-01-11  1.386963    0.917477    1.876433
# 2   2015-01-18  1.382228    0.891497    1.894913
# 3   2015-01-25  1.358221    0.921002    1.847334
# 4   2015-02-01  1.324859    0.814734    1.824705
# ..         ...       ...         ...         ...
# 529 2019-03-21  1.073351    0.574727    1.577600
# 530 2019-03-22  1.074317    0.516099    1.566095
# 531 2019-03-23  1.075557    0.556988    1.612352
# 532 2019-03-24  1.077052    0.570104    1.585825
# 533 2019-03-25  1.078773    0.536074    1.616095
#
# [534 rows x 4 columns]

# %%
figure=model.plot_components(forecast)
